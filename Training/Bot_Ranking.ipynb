# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import math

from keras.layers import Embedding, Dense, LSTM, Dense, Input, concatenate
from keras.models import Model
import tensorflow as tf
from keras.preprocessing import text, sequence
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import datetime

# %%
df_all_bots=pd.read_csv('/content/drive/MyDrive/SAAS-2121/Datasets/mini_datasets/mini_bots.csv',error_bad_lines=False)

# %%
df_all_bots
# Out:
#        Unnamed: 0  Unnamed: 0.1  ...  traditional_spambot fake_followers
# 0           45520         97838  ...                    0              1
# 1           76693       1337471  ...                    0              0
# 2           60243        467388  ...                    0              0
# 3           32546         57978  ...                    1              0
# 4           21229         30147  ...                    1              0
# ...           ...           ...  ...                  ...            ...
# 88541      104153        102733  ...                    1              0
# 88542        3405       1057626  ...                    0              0
# 88543       74504       1053471  ...                    0              0
# 88544       72438       1550514  ...                    0              0
# 88545       69610         81331  ...                    0              1
#
# [88546 rows x 31 columns]
